# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_excel(r"D:\FingerTip's\Panda's Class 1\ML Live Flight Fare Resourses16963295320.xlsx")

# %%
data
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
data.shape
# Out:
# (10683, 11)

# %%
data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
data.drop(["Additional_Info","Route"],axis=1,inplace=True)

# %%
data.head(1)
# Out:
#   Airline Date_of_Journey    Source Destination Dep_Time  Arrival_Time  \
# 0  IndiGo      24/03/2019  Banglore   New Delhi    22:20  01:10 22 Mar
#
#   Duration Total_Stops  Price
# 0   2h 50m    non-stop   3897

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Dep_Time         10683 non-null  object
#  5   Arrival_Time     10683 non-null  object
#  6   Duration         10683 non-null  object
#  7   Total_Stops      10682 non-null  object
#  8   Price            10683 non-null  int64
# dtypes: int64(1), object(8)
# memory usage: 751.3+ KB

# %%
data.isnull().any()
# Out:
# Airline            False
# Date_of_Journey    False
# Source             False
# Destination        False
# Dep_Time           False
# Arrival_Time       False
# Duration           False
# Total_Stops         True
# Price              False
# dtype: bool

# %%
data.head(5)
# Out:
#        Airline Date_of_Journey    Source Destination Dep_Time  Arrival_Time  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi    22:20  01:10 22 Mar
# 1    Air India       1/05/2019   Kolkata    Banglore    05:50         13:15
# 2  Jet Airways       9/06/2019     Delhi      Cochin    09:25  04:25 10 Jun
# 3       IndiGo      12/05/2019   Kolkata    Banglore    18:05         23:30
# 4       IndiGo      01/03/2019  Banglore   New Delhi    16:50         21:35
#
#   Duration Total_Stops  Price
# 0   2h 50m    non-stop   3897
# 1   7h 25m     2 stops   7662
# 2      19h     2 stops  13882
# 3   5h 25m      1 stop   6218
# 4   4h 45m      1 stop  13302

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
data["Day_of_Journey"]=pd.to_datetime(data["Date_of_Journey"]).dt.day
data["Month_of_Journey"]=pd.to_datetime(data["Date_of_Journey"]).dt.month
data["Year_of_Journey"]=pd.to_datetime(data["Date_of_Journey"]).dt.year

# %%
data.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination Dep_Time  Arrival_Time  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi    22:20  01:10 22 Mar
# 1  Air India       1/05/2019   Kolkata    Banglore    05:50         13:15
#
#   Duration Total_Stops  Price  Day_of_Journey  Month_of_Journey  \
# 0   2h 50m    non-stop   3897              24                 3
# 1   7h 25m     2 stops   7662               1                 5
#
#    Year_of_Journey
# 0             2019
# 1             2019

# %%
data.drop("Year_of_Journey",axis=1,inplace=True)

# %%
data.head(1)
# Out:
#   Airline Date_of_Journey    Source Destination Dep_Time  Arrival_Time  \
# 0  IndiGo      24/03/2019  Banglore   New Delhi    22:20  01:10 22 Mar
#
#   Duration Total_Stops  Price  Day_of_Journey  Month_of_Journey
# 0   2h 50m    non-stop   3897              24                 3

# %%
data["Dept_Minute"]=pd.to_datetime(data["Dep_Time"]).dt.minute
data["Dept_Hour"]=pd.to_datetime(data["Dep_Time"]).dt.hour

# %%
data.drop("Dep_Time",axis=1,inplace=True)

# %%
data.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination  Arrival_Time Duration  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi  01:10 22 Mar   2h 50m
# 1  Air India       1/05/2019   Kolkata    Banglore         13:15   7h 25m
#
#   Total_Stops  Price  Day_of_Journey  Month_of_Journey  Dept_Minute  Dept_Hour
# 0    non-stop   3897              24                 3           20         22
# 1     2 stops   7662               1                 5           50          5

# %%
data["Arrival_Minute"]=pd.to_datetime(data["Arrival_Time"]).dt.minute
data["Arrival_Hour"]=pd.to_datetime(data["Arrival_Time"]).dt.hour

# %%
data.drop("Arrival_Time",axis=1,inplace=True)

# %%
data.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination Duration Total_Stops  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi   2h 50m    non-stop
# 1  Air India       1/05/2019   Kolkata    Banglore   7h 25m     2 stops
#
#    Price  Day_of_Journey  Month_of_Journey  Dept_Minute  Dept_Hour  \
# 0   3897              24                 3           20         22
# 1   7662               1                 5           50          5
#
#    Arrival_Minute  Arrival_Hour
# 0              10             1
# 1              15            13

# %%
data.groupby("Airline")["Price"].mean().plot(figsize=(10,5))
# Out:
# <Axes: xlabel='Airline'>

# %%
Airline=pd.get_dummies(data["Airline"])

# %%
data.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination Duration Total_Stops  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi   2h 50m    non-stop
# 1  Air India       1/05/2019   Kolkata    Banglore   7h 25m     2 stops
#
#    Price  Day_of_Journey  Month_of_Journey  Dept_Minute  Dept_Hour  \
# 0   3897              24                 3           20         22
# 1   7662               1                 5           50          5
#
#    Arrival_Minute  Arrival_Hour
# 0              10             1
# 1              15            13

# %%
data.groupby("Source")["Price"].mean().plot(figsize=(10,5))
# Out:
# <Axes: xlabel='Source'>

# %%
Source=pd.get_dummies(data["Source"])

# %%
data.groupby("Destination")["Price"].mean().plot(figsize=(10,5))
# Out:
# <Axes: xlabel='Destination'>

# %%
Destination=pd.get_dummies(data["Destination"])

# %%
data.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination Duration Total_Stops  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi   2h 50m    non-stop
# 1  Air India       1/05/2019   Kolkata    Banglore   7h 25m     2 stops
#
#    Price  Day_of_Journey  Month_of_Journey  Dept_Minute  Dept_Hour  \
# 0   3897              24                 3           20         22
# 1   7662               1                 5           50          5
#
#    Arrival_Minute  Arrival_Hour
# 0              10             1
# 1              15            13

# %%
data["Total_Stops"].unique()
# Out:
# array(['non-stop', '2 stops', '1 stop', '3 stops', nan, '4 stops'],
#       dtype=object)

# %%
data["Total_Stops"]=data["Total_Stops"].replace(['non-stop', '2 stops', '1 stop', '3 stops','4 stops'],[0,2,1,3,4])

# %%
data.head(5)
# Out:
#        Airline Date_of_Journey    Source Destination Duration  Total_Stops  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi   2h 50m          0.0
# 1    Air India       1/05/2019   Kolkata    Banglore   7h 25m          2.0
# 2  Jet Airways       9/06/2019     Delhi      Cochin      19h          2.0
# 3       IndiGo      12/05/2019   Kolkata    Banglore   5h 25m          1.0
# 4       IndiGo      01/03/2019  Banglore   New Delhi   4h 45m          1.0
#
#    Price  Day_of_Journey  Month_of_Journey  Dept_Minute  Dept_Hour  \
# 0   3897              24                 3           20         22
# 1   7662               1                 5           50          5
# 2  13882               9                 6           25          9
# 3   6218              12                 5            5         18
# 4  13302               1                 3           50         16
#
#    Arrival_Minute  Arrival_Hour
# 0              10             1
# 1              15            13
# ...

# %%
data.drop(["Airline","Source","Destination"],axis=1,inplace=True)

# %%
data.head(2)
# Out:
#   Date_of_Journey Duration  Total_Stops  Price  Day_of_Journey  \
# 0      24/03/2019   2h 50m          0.0   3897              24
# 1       1/05/2019   7h 25m          2.0   7662               1
#
#    Month_of_Journey  Dept_Minute  Dept_Hour  Arrival_Minute  Arrival_Hour
# 0                 3           20         22              10             1
# 1                 5           50          5              15            13

# %%
data.drop("Date_of_Journey",axis=1,inplace=True)

# %%
data.head(1)
# Out:
#   Duration  Total_Stops  Price  Day_of_Journey  Month_of_Journey  Dept_Minute  \
# 0   2h 50m          0.0   3897              24                 3           20
#
#    Dept_Hour  Arrival_Minute  Arrival_Hour
# 0         22              10             1

# %%
data=pd.concat([data,Airline,Source,Destination],axis=1)

# %%
pd.set_option("display.max_columns",None)

# %%
data.head(2)
# Out:
#   Duration  Total_Stops  Price  Day_of_Journey  Month_of_Journey  Dept_Minute  \
# 0   2h 50m          0.0   3897              24                 3           20
# 1   7h 25m          2.0   7662               1                 5           50
#
#    Dept_Hour  Arrival_Minute  Arrival_Hour  Air Asia  Air India  GoAir  \
# 0         22              10             1     False      False  False
# 1          5              15            13     False       True  False
#
#    IndiGo  Jet Airways  Jet Airways Business  Multiple carriers  \
# 0    True        False                 False              False
# 1   False        False                 False              False
#
#    Multiple carriers Premium economy  SpiceJet  Trujet  Vistara  \
# 0                              False     False   False    False
# 1                              False     False   False    False
#
#    Vistara Premium economy  Banglore  Chennai  Delhi  Kolkata  Mumbai  \
# ...

# %%
data["Duration_Hour"]=data["Duration"].str.split().str[0]
data["Duration_Minute"]=data["Duration"].str.split().str[1]

# %%
data.head(1)
# Out:
#   Duration  Total_Stops  Price  Day_of_Journey  Month_of_Journey  Dept_Minute  \
# 0   2h 50m          0.0   3897              24                 3           20
#
#    Dept_Hour  Arrival_Minute  Arrival_Hour  Air Asia  Air India  GoAir  \
# 0         22              10             1     False      False  False
#
#    IndiGo  Jet Airways  Jet Airways Business  Multiple carriers  \
# 0    True        False                 False              False
#
#    Multiple carriers Premium economy  SpiceJet  Trujet  Vistara  \
# 0                              False     False   False    False
#
#    Vistara Premium economy  Banglore  Chennai  Delhi  Kolkata  Mumbai  \
# 0                    False      True    False  False    False   False
#
#    Banglore  Cochin  Delhi  Hyderabad  Kolkata  New Delhi Duration_Hour  \
# 0     False   False  False      False    False       True            2h
#
#   Duration_Minute
# 0             50m

# %%
data.drop("Duration",axis=1,inplace=True)

# %%
data.head(10)
# Out:
#    Total_Stops  Price  Day_of_Journey  Month_of_Journey  Dept_Minute  \
# 0          0.0   3897              24                 3           20
# 1          2.0   7662               1                 5           50
# 2          2.0  13882               9                 6           25
# 3          1.0   6218              12                 5            5
# 4          1.0  13302               1                 3           50
# 5          0.0   3873              24                 6            0
# 6          1.0  11087              12                 3           55
# 7          1.0  22270               1                 3            0
# 8          1.0  11087              12                 3           55
# 9          1.0   8625              27                 5           25
#
#    Dept_Hour  Arrival_Minute  Arrival_Hour  Air Asia  Air India  GoAir  \
# 0         22              10             1     False      False  False
# ...

# %%
data.fillna(0,inplace=True)

# %%
data.head()
# Out:
#    Total_Stops  Price  Day_of_Journey  Month_of_Journey  Dept_Minute  \
# 0          0.0   3897              24                 3           20
# 1          2.0   7662               1                 5           50
# 2          2.0  13882               9                 6           25
# 3          1.0   6218              12                 5            5
# 4          1.0  13302               1                 3           50
#
#    Dept_Hour  Arrival_Minute  Arrival_Hour  Air Asia  Air India  GoAir  \
# 0         22              10             1     False      False  False
# 1          5              15            13     False       True  False
# 2          9              25             4     False      False  False
# 3         18              30            23     False      False  False
# 4         16              35            21     False      False  False
#
#    IndiGo  Jet Airways  Jet Airways Business  Multiple carriers  \
# ...

# %%
data["Duration_Hour"]=data["Duration_Hour"].replace("[h]","",regex=True)
data["Duration_Minute"]=data["Duration_Minute"].replace("[m]","",regex=True)

# %%
data.head()
# Out:
#    Total_Stops  Price  Day_of_Journey  Month_of_Journey  Dept_Minute  \
# 0          0.0   3897              24                 3           20
# 1          2.0   7662               1                 5           50
# 2          2.0  13882               9                 6           25
# 3          1.0   6218              12                 5            5
# 4          1.0  13302               1                 3           50
#
#    Dept_Hour  Arrival_Minute  Arrival_Hour  Air Asia  Air India  GoAir  \
# 0         22              10             1     False      False  False
# 1          5              15            13     False       True  False
# 2          9              25             4     False      False  False
# 3         18              30            23     False      False  False
# 4         16              35            21     False      False  False
#
#    IndiGo  Jet Airways  Jet Airways Business  Multiple carriers  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 33 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Total_Stops                        10683 non-null  float64
#  1   Price                              10683 non-null  int64
#  2   Day_of_Journey                     10683 non-null  int32
#  3   Month_of_Journey                   10683 non-null  int32
#  4   Dept_Minute                        10683 non-null  int32
#  5   Dept_Hour                          10683 non-null  int32
#  6   Arrival_Minute                     10683 non-null  int32
#  7   Arrival_Hour                       10683 non-null  int32
#  8   Air Asia                           10683 non-null  bool
#  9   Air India                          10683 non-null  bool
#  10  GoAir                              10683 non-null  bool
# ...

# %%
data["Duration_Hour"]=data["Duration_Hour"].replace("[m]","",regex=True)

# %%
data.head(5)
# Out:
#    Total_Stops  Price  Day_of_Journey  Month_of_Journey  Dept_Minute  \
# 0          0.0   3897              24                 3           20
# 1          2.0   7662               1                 5           50
# 2          2.0  13882               9                 6           25
# 3          1.0   6218              12                 5            5
# 4          1.0  13302               1                 3           50
#
#    Dept_Hour  Arrival_Minute  Arrival_Hour  Air Asia  Air India  GoAir  \
# 0         22              10             1     False      False  False
# 1          5              15            13     False       True  False
# 2          9              25             4     False      False  False
# 3         18              30            23     False      False  False
# 4         16              35            21     False      False  False
#
#    IndiGo  Jet Airways  Jet Airways Business  Multiple carriers  \
# ...

# %%
data[["Duration_Hour","Duration_Minute"]]=data[["Duration_Hour","Duration_Minute"]].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 33 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Total_Stops                        10683 non-null  float64
#  1   Price                              10683 non-null  int64
#  2   Day_of_Journey                     10683 non-null  int32
#  3   Month_of_Journey                   10683 non-null  int32
#  4   Dept_Minute                        10683 non-null  int32
#  5   Dept_Hour                          10683 non-null  int32
#  6   Arrival_Minute                     10683 non-null  int32
#  7   Arrival_Hour                       10683 non-null  int32
#  8   Air Asia                           10683 non-null  bool
#  9   Air India                          10683 non-null  bool
#  10  GoAir                              10683 non-null  bool
# ...

# %%
x=data.drop("Price",axis=True)
y=data["Price"]

# %%
data.shape
# Out:
# (10683, 33)

# %%
data.head(5)
# Out:
#    Total_Stops  Price  Day_of_Journey  Month_of_Journey  Dept_Minute  \
# 0          0.0   3897              24                 3           20
# 1          2.0   7662               1                 5           50
# 2          2.0  13882               9                 6           25
# 3          1.0   6218              12                 5            5
# 4          1.0  13302               1                 3           50
#
#    Dept_Hour  Arrival_Minute  Arrival_Hour  Air Asia  Air India  GoAir  \
# 0         22              10             1     False      False  False
# 1          5              15            13     False       True  False
# 2          9              25             4     False      False  False
# 3         18              30            23     False      False  False
# 4         16              35            21     False      False  False
#
#    IndiGo  Jet Airways  Jet Airways Business  Multiple carriers  \
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# Training Accurecy
model.score(x_train,y_train)*100
# Out:
# 62.515376326119856

# %%
# Testing Accurecy
model.score(x_test,y_test)*100
# Out:
# 61.49468084965836

# %%
from sklearn.linear_model import Ridge, Lasso
model1=Ridge(10)
model2=Lasso(10)

# %%
model1.fit(x_train,y_train)
model2.fit(x_train,y_train)
# Out:
# Lasso(alpha=10)

# %%
# Ridge
print("Training Accuracy",model1.score(x_train,y_train))
print("Teesting Accuracy",model1.score(x_test,y_test))
# Out:
# Training Accuracy 0.600927123479619
# Teesting Accuracy 0.5967610079517356

# %%
# Lasso
print("Training Accuracy",model2.score(x_train,y_train))
print("TTesting Accuracy",model2.score(x_test,y_test))
# Out:
# Training Accuracy 0.6156467553364511
# TTesting Accuracy 0.6057403949801832

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.svm import SVR

# %%
all_model = [DecisionTreeRegressor,KNeighborsRegressor,RandomForestRegressor,AdaBoostRegressor,SVR]
for i in all_model:
    model= i()
    model=model.fit(x_train,y_train)
    print(i,"accuracy",model.score(x_test,y_test))
# Out:
# <class 'sklearn.tree._classes.DecisionTreeRegressor'> accuracy 0.6485055756948204
# <class 'sklearn.neighbors._regression.KNeighborsRegressor'> accuracy 0.5411319051228314
# <class 'sklearn.ensemble._forest.RandomForestRegressor'> accuracy 0.7844306067017964
# <class 'sklearn.ensemble._weight_boosting.AdaBoostRegressor'> accuracy 0.5574496640193495
# <class 'sklearn.svm._classes.SVR'> accuracy -0.0022975681982631

# %% [markdown]
# # K_Fold and Cross_Validation_Technique

# %%
 from sklearn.model_selection import KFold,cross_val_score

# %%
models=[]
models.append(('KNN', KNeighborsRegressor()))
models.append(('DecissionTree',DecisionTreeRegressor()))
models.append(('RF',RandomForestRegressor()))
models.append(('SVR',SVR()))
models.append(('AdaBoost',AdaBoostRegressor()))

# %%
results=[]
names=[]
for name,model in models:
    kfold=KFold(5)
    cv_result=cross_val_score(model,x_train,y_train,cv=kfold)
    names.append(name)
    results.append(cv_result)

# %%
for i in range(len(names)):
    print(names[i],results[i].mean())
# Out:
# KNN 0.5542572223243143
# DecissionTree 0.7015055196915849
# RF 0.806101862108612
# SVR -0.0016636149908503262
# AdaBoost 0.4368643499649001

# %% [markdown]
# # We see Random Forest Regressor gives us best score so we can use Random Forest Regressor algorithm

# %%
from sklearn.ensemble import RandomForestRegressor
model = RandomForestRegressor()
model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = model.predict(x_test)

# %%
model.score(x_train,y_train)*100
# Out:
# 95.39646831229575

# %%
model.score(x_test,y_test)*100
# Out:
# 78.46713032725387

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 1198.3770221147333

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 4557209.228353817

# %%
r2_score(y_test,y_pred)*100
# Out:
# 78.46713032725387

# %% [markdown]
# # Hyper_Parameter_tuning

# %%
import numpy as np

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
np.linspace(100,1200,12)
# Out:
# array([ 100.,  200.,  300.,  400.,  500.,  600.,  700.,  800.,  900.,
#        1000., 1100., 1200.])

# %%
np.linspace(5,30,6)
# Out:
# array([ 5., 10., 15., 20., 25., 30.])

# %% [markdown]
# # Possiable_Parameter

# %%
n_estimators=[[ 100.,  200.,  300.,  400.,  500.,  600.,  700.,  800.,  900.,
       1000., 1100., 1200.]]
max_features = ['auto','sqrt']
max_depth = [ 5., 10., 15., 20., 25., 30.]
min_samples_split = [2,5,10,15,100]
min_samples_leaf = [1,2,5,10]

# %%
random_grid = {'n_estimators':n_estimators,
              'max_features':max_features,
              'max_depth':max_depth,
              'min_samples_split':min_samples_split,
              'min_samples_leaf':min_samples_leaf}

# %%
model.base_estimator
# Out:
# 'deprecated'

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
mean_absolute_error(y_test,y_pred)
# Out:
# 1198.3770221147333

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 4557209.228353817

# %%
r2_score(y_test,y_pred)*100
# Out:
# 78.46713032725387
